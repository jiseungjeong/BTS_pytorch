# %% [markdown]
# # 01. 로지스틱 회귀

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 6.3 MB/s eta 0:00:01    |█                               | 348 kB 2.8 MB/s eta 0:00:04[K     |██████████████████████████████▍ | 10.7 MB 6.3 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jiseungjeong/.local/lib/python3.8/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: numpy>=1.17 in /home/jiseungjeong/.local/lib/python3.8/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jiseungjeong/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 9.9 MB/s eta 0:00:01     |█████████████████████████▏      | 921 kB 9.9 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 7.4 MB/s eta 0:00:01     |██████████████████████████▍     | 3.6 MB 6.4 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.1-py3-none-any.whl (899 kB)
#      |████████████████████████████████| 899 kB 6.0 MB/s eta 0:00:01     |████████████████                | 450 kB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/jiseungjeong/.local/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Installing collected packages: kiwisolver, cycler, pillow, fonttools, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.31.1 kiwisolver-1.4.0 matplotlib-3.5.1 pillow-9.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline 
# 새로운 창을 만들지 않음
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %% [markdown]
# ## 1. W가 1이고 b가 0인 그래프

# %%
x=np.arange(-5.0,5.0,0.1)
y=sigmoid(x)

plt.plot(x,y,'g')
plt.plot([0,0],[0.0,1.0],':') # 가운데 점선 추가
plt.title('Sigmoid Function')
plt.show()

# %% [markdown]
# ## 2. W값의 변화에 따른 경사도의 변화

# %%
x=np.arange(-5.0, 5.0, 0.1)
y1=sigmoid(0.5*x)
y2=sigmoid(x)
y3=sigmoid(2*x)

plt.plot(x,y1,'r',linestyle='--')
plt.plot(x,y2,'g')
plt.plot(x,y3,'b',linestyle='--')

plt.plot([0,0],[1.0,0.0],':')
plt.title('Sigmoid Function')
plt.show()

# %% [markdown]
# ## 3. b값 변화에 따른 좌, 우 이동

# %%
x=np.arange(-5.0, 5.0, 0.1)
y1=sigmoid(x+0.5)
y2=sigmoid(x+1)
y3=sigmoid(x+1.5)

plt.plot(x,y1,'r',linestyle='--')
plt.plot(x,y2,'g')
plt.plot(x,y3,'b',linestyle='--')
plt.plot([0,0],[1.0,0.0],':')
plt.title('Sigmoid Function')
plt.show()

# %% [markdown]
# ## 4. 파이토치로 로지스틱 회귀 구현

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
x_data=[[1,2],[2,3],[3,1],[4,3],[5,3],[6,2]]
y_data=[[0],[0],[0],[1],[1],[1]]
x_train=torch.FloatTensor(x_data)
y_train=torch.FloatTensor(y_data)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# torch.Size([6, 2])
# torch.Size([6, 1])

# %%
W=torch.zeros((2,1),requires_grad=True)
b=torch.zeros(1, requires_grad=True)

# %%
hypothesis=1/(1+torch.exp(-(x_train.matmul(W)+b)))

# %%
print(hypothesis)
print(y_train)
# Out:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]], grad_fn=<MulBackward0>)
# tensor([[0.],
#         [0.],
#         [0.],
#         [1.],
#         [1.],
#         [1.]])

# %%
-(y_train[0]*torch.log(hypothesis[0])+(1-y_train[0])*torch.log(1-hypothesis[0]))
# Out:
# tensor([0.6931], grad_fn=<NegBackward0>)

# %%
losses=-(y_train*torch.log(hypothesis)+(1-y_train)*torch.log(1-hypothesis))
print(losses)
# Out:
# tensor([[0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931]], grad_fn=<NegBackward0>)

# %%
cost=losses.mean()
print(cost)
# Out:
# tensor(0.6931, grad_fn=<MeanBackward0>)

# %%
F.binary_cross_entropy(hypothesis, y_train)
# Out:
# tensor(0.6931, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
x_data=[[1,2],[2,3],[3,1],[4,3],[5,3],[6,2]]
y_data=[[0],[0],[0],[1],[1],[1]]
x_train=torch.FloatTensor(x_data)
y_train=torch.FloatTensor(y_data)

# %%
W=torch.zeros((2,1),requires_grad=True)
b=torch.zeros(1, requires_grad=True)

optimizer=optim.SGD([W,b],lr=1)

nb_epochs=1000
for epoch in range(nb_epochs+1):
    hypothesis=torch.sigmoid(x_train.matmul(W)+b)
    cost=-(y_train*torch.log(hypothesis)+(1-y_train)*torch.log(1-hypothesis)).mean()
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch    0/1000 Cost: 0.693147
# Epoch  100/1000 Cost: 0.134722
# Epoch  200/1000 Cost: 0.080643
# Epoch  300/1000 Cost: 0.057900
# Epoch  400/1000 Cost: 0.045300
# Epoch  500/1000 Cost: 0.037261
# Epoch  600/1000 Cost: 0.031673
# Epoch  700/1000 Cost: 0.027556
# Epoch  800/1000 Cost: 0.024394
# Epoch  900/1000 Cost: 0.021888
# Epoch 1000/1000 Cost: 0.019852

# %%
hypothesis=torch.sigmoid(x_train.matmul(W)+b)
print(hypothesis)
# Out:
# tensor([[2.7648e-04],
#         [3.1608e-02],
#         [3.8977e-02],
#         [9.5622e-01],
#         [9.9823e-01],
#         [9.9969e-01]], grad_fn=<SigmoidBackward0>)

# %%
prediction=hypothesis>=torch.FloatTensor([0.5])
print(prediction)
# Out:
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])

# %%
print(W)
print(b)
# Out:
# tensor([[3.2530],
#         [1.5179]], requires_grad=True)
# tensor([-14.4819], requires_grad=True)

# %% [markdown]
# # 02. nn.Module로 구현하는 로지스틱 회귀

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as opotim

# %%
torch.manual_seed(1)

# %%
x_data=[[1,2],[2,3],[3,1],[4,3],[5,3],[6,2]]
y_data=[[0],[0],[0],[1],[1],[1]]
x_train=torch.FloatTensor(x_data)
y_train=torch.FloatTensor(y_data)

# %%
model=nn.Sequential(
    nn.Linear(2,1),
    nn.Sigmoid()
)

# %%
model(x_train)
# Out:
# tensor([[0.4020],
#         [0.4147],
#         [0.6556],
#         [0.5948],
#         [0.6788],
#         [0.8061]], grad_fn=<SigmoidBackward0>)

# %%
optimizer=optim.SGD(model.parameters(), lr=1)

nb_epochs=1000
for epoch in range(nb_epochs +1):
    hypothesis=model(x_train)
    
    cost=F.binary_cross_entropy(hypothesis,y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%10==0:
        prediction=hypothesis>=torch.FloatTensor([0.5])
        correct_prediction=prediction.float()==y_train
        accuracy=correct_prediction.sum().item()/len(correct_prediction)
        print('Epoch {:4d}/{} Cost: {:.6f} Accuracy {:2.2f}%'.format(epoch, nb_epochs, cost.item(), accuracy*100))
# Out:
# Epoch    0/1000 Cost: 0.539713 Accuracy 83.33%
# Epoch   10/1000 Cost: 0.614853 Accuracy 66.67%
# Epoch   20/1000 Cost: 0.441875 Accuracy 66.67%
# Epoch   30/1000 Cost: 0.373145 Accuracy 83.33%
# Epoch   40/1000 Cost: 0.316358 Accuracy 83.33%
# Epoch   50/1000 Cost: 0.266094 Accuracy 83.33%
# Epoch   60/1000 Cost: 0.220498 Accuracy 100.00%
# Epoch   70/1000 Cost: 0.182095 Accuracy 100.00%
# Epoch   80/1000 Cost: 0.157299 Accuracy 100.00%
# Epoch   90/1000 Cost: 0.144091 Accuracy 100.00%
# Epoch  100/1000 Cost: 0.134272 Accuracy 100.00%
# Epoch  110/1000 Cost: 0.125769 Accuracy 100.00%
# Epoch  120/1000 Cost: 0.118297 Accuracy 100.00%
# Epoch  130/1000 Cost: 0.111680 Accuracy 100.00%
# Epoch  140/1000 Cost: 0.105779 Accuracy 100.00%
# Epoch  150/1000 Cost: 0.100483 Accuracy 100.00%
# Epoch  160/1000 Cost: 0.095704 Accuracy 100.00%
# Epoch  170/1000 Cost: 0.091369 Accuracy 100.00%
# Epoch  180/1000 Cost: 0.087420 Accuracy 100.00%
# Epoch  190/1000 Cost: 0.083806 Accuracy 100.00%
# Epoch  200/1000 Cost: 0.080486 Accuracy 100.00%
# Epoch  210/1000 Cost: 0.077425 Accuracy 100.00%
# Epoch  220/1000 Cost: 0.074595 Accuracy 100.00%
# Epoch  230/1000 Cost: 0.071969 Accuracy 100.00%
# Epoch  240/1000 Cost: 0.069526 Accuracy 100.00%
# Epoch  250/1000 Cost: 0.067248 Accuracy 100.00%
# Epoch  260/1000 Cost: 0.065118 Accuracy 100.00%
# Epoch  270/1000 Cost: 0.063122 Accuracy 100.00%
# Epoch  280/1000 Cost: 0.061247 Accuracy 100.00%
# Epoch  290/1000 Cost: 0.059483 Accuracy 100.00%
# Epoch  300/1000 Cost: 0.057820 Accuracy 100.00%
# Epoch  310/1000 Cost: 0.056250 Accuracy 100.00%
# Epoch  320/1000 Cost: 0.054764 Accuracy 100.00%
# Epoch  330/1000 Cost: 0.053357 Accuracy 100.00%
# Epoch  340/1000 Cost: 0.052022 Accuracy 100.00%
# Epoch  350/1000 Cost: 0.050753 Accuracy 100.00%
# Epoch  360/1000 Cost: 0.049546 Accuracy 100.00%
# Epoch  370/1000 Cost: 0.048396 Accuracy 100.00%
# Epoch  380/1000 Cost: 0.047299 Accuracy 100.00%
# Epoch  390/1000 Cost: 0.046252 Accuracy 100.00%
# Epoch  400/1000 Cost: 0.045251 Accuracy 100.00%
# Epoch  410/1000 Cost: 0.044294 Accuracy 100.00%
# Epoch  420/1000 Cost: 0.043376 Accuracy 100.00%
# Epoch  430/1000 Cost: 0.042497 Accuracy 100.00%
# Epoch  440/1000 Cost: 0.041653 Accuracy 100.00%
# Epoch  450/1000 Cost: 0.040843 Accuracy 100.00%
# Epoch  460/1000 Cost: 0.040064 Accuracy 100.00%
# Epoch  470/1000 Cost: 0.039315 Accuracy 100.00%
# Epoch  480/1000 Cost: 0.038593 Accuracy 100.00%
# Epoch  490/1000 Cost: 0.037898 Accuracy 100.00%
# Epoch  500/1000 Cost: 0.037228 Accuracy 100.00%
# Epoch  510/1000 Cost: 0.036582 Accuracy 100.00%
# Epoch  520/1000 Cost: 0.035958 Accuracy 100.00%
# Epoch  530/1000 Cost: 0.035356 Accuracy 100.00%
# Epoch  540/1000 Cost: 0.034773 Accuracy 100.00%
# Epoch  550/1000 Cost: 0.034210 Accuracy 100.00%
# Epoch  560/1000 Cost: 0.033664 Accuracy 100.00%
# Epoch  570/1000 Cost: 0.033137 Accuracy 100.00%
# Epoch  580/1000 Cost: 0.032625 Accuracy 100.00%
# Epoch  590/1000 Cost: 0.032130 Accuracy 100.00%
# Epoch  600/1000 Cost: 0.031649 Accuracy 100.00%
# Epoch  610/1000 Cost: 0.031183 Accuracy 100.00%
# Epoch  620/1000 Cost: 0.030730 Accuracy 100.00%
# Epoch  630/1000 Cost: 0.030291 Accuracy 100.00%
# Epoch  640/1000 Cost: 0.029864 Accuracy 100.00%
# Epoch  650/1000 Cost: 0.029449 Accuracy 100.00%
# Epoch  660/1000 Cost: 0.029046 Accuracy 100.00%
# Epoch  670/1000 Cost: 0.028654 Accuracy 100.00%
# Epoch  680/1000 Cost: 0.028272 Accuracy 100.00%
# Epoch  690/1000 Cost: 0.027900 Accuracy 100.00%
# Epoch  700/1000 Cost: 0.027538 Accuracy 100.00%
# Epoch  710/1000 Cost: 0.027186 Accuracy 100.00%
# Epoch  720/1000 Cost: 0.026842 Accuracy 100.00%
# Epoch  730/1000 Cost: 0.026507 Accuracy 100.00%
# Epoch  740/1000 Cost: 0.026181 Accuracy 100.00%
# Epoch  750/1000 Cost: 0.025862 Accuracy 100.00%
# Epoch  760/1000 Cost: 0.025552 Accuracy 100.00%
# Epoch  770/1000 Cost: 0.025248 Accuracy 100.00%
# Epoch  780/1000 Cost: 0.024952 Accuracy 100.00%
# Epoch  790/1000 Cost: 0.024663 Accuracy 100.00%
# Epoch  800/1000 Cost: 0.024381 Accuracy 100.00%
# Epoch  810/1000 Cost: 0.024104 Accuracy 100.00%
# Epoch  820/1000 Cost: 0.023835 Accuracy 100.00%
# Epoch  830/1000 Cost: 0.023571 Accuracy 100.00%
# Epoch  840/1000 Cost: 0.023313 Accuracy 100.00%
# Epoch  850/1000 Cost: 0.023061 Accuracy 100.00%
# Epoch  860/1000 Cost: 0.022814 Accuracy 100.00%
# Epoch  870/1000 Cost: 0.022572 Accuracy 100.00%
# Epoch  880/1000 Cost: 0.022336 Accuracy 100.00%
# Epoch  890/1000 Cost: 0.022104 Accuracy 100.00%
# Epoch  900/1000 Cost: 0.021877 Accuracy 100.00%
# Epoch  910/1000 Cost: 0.021655 Accuracy 100.00%
# Epoch  920/1000 Cost: 0.021437 Accuracy 100.00%
# Epoch  930/1000 Cost: 0.021224 Accuracy 100.00%
# Epoch  940/1000 Cost: 0.021015 Accuracy 100.00%
# Epoch  950/1000 Cost: 0.020810 Accuracy 100.00%
# Epoch  960/1000 Cost: 0.020609 Accuracy 100.00%
# Epoch  970/1000 Cost: 0.020412 Accuracy 100.00%
# Epoch  980/1000 Cost: 0.020219 Accuracy 100.00%
# Epoch  990/1000 Cost: 0.020029 Accuracy 100.00%
# Epoch 1000/1000 Cost: 0.019843 Accuracy 100.00%

# %%
model(x_train)
# Out:
# tensor([[2.7616e-04],
#         [3.1595e-02],
#         [3.8959e-02],
#         [9.5624e-01],
#         [9.9823e-01],
#         [9.9969e-01]], grad_fn=<SigmoidBackward0>)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[3.2534, 1.5181]], requires_grad=True), Parameter containing:
# tensor([-14.4839], requires_grad=True)]

# %% [markdown]
# # 03. 클래스로 파이토치 모델 구현하기

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
x_data=[[1,2],[2,3],[3,1],[4,3],[5,3],[6,2]]
y_data=[[0],[0],[0],[1],[1],[1]]
x_train=torch.FloatTensor(x_data)
y_train=torch.FloatTensor(y_data)

# %%
class BinaryClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(2,1)
        self.sigmoid=nn.Sigmoid()
    
    def forward(self,x):
        return self.sigmoid(self.linear(x))

# %%
model=BinaryClassifier()

# %%
optimizer=optim.SGD(model.parameters(),lr=1)

nb_epochs=1000
for epoch in range(nb_epochs+1):
    hypothesis=model(x_train)
    cost=F.binary_cross_entropy(hypothesis, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%10==0:
        prediction=hypothesis>=torch.FloatTensor([0.5])
        correct_prediction=prediction.float() == y_train
        accuracy=correct_prediction.sum().item()/len(correct_prediction)
        print('Epoch {:4d}/{} Cost: {:.6f} Accuracy {:2.2f}%'.format(epoch, nb_epochs, cost.item(), accuracy*100))
# Out:
# Epoch    0/1000 Cost: 0.725765 Accuracy 33.33%
# Epoch   10/1000 Cost: 0.452269 Accuracy 83.33%
# Epoch   20/1000 Cost: 0.603033 Accuracy 83.33%
# Epoch   30/1000 Cost: 0.485839 Accuracy 83.33%
# Epoch   40/1000 Cost: 0.399292 Accuracy 83.33%
# Epoch   50/1000 Cost: 0.317865 Accuracy 83.33%
# Epoch   60/1000 Cost: 0.244316 Accuracy 83.33%
# Epoch   70/1000 Cost: 0.188225 Accuracy 100.00%
# Epoch   80/1000 Cost: 0.158080 Accuracy 100.00%
# Epoch   90/1000 Cost: 0.144390 Accuracy 100.00%
# Epoch  100/1000 Cost: 0.134524 Accuracy 100.00%
# Epoch  110/1000 Cost: 0.125989 Accuracy 100.00%
# Epoch  120/1000 Cost: 0.118492 Accuracy 100.00%
# Epoch  130/1000 Cost: 0.111853 Accuracy 100.00%
# Epoch  140/1000 Cost: 0.105933 Accuracy 100.00%
# Epoch  150/1000 Cost: 0.100622 Accuracy 100.00%
# Epoch  160/1000 Cost: 0.095830 Accuracy 100.00%
# Epoch  170/1000 Cost: 0.091484 Accuracy 100.00%
# Epoch  180/1000 Cost: 0.087524 Accuracy 100.00%
# Epoch  190/1000 Cost: 0.083901 Accuracy 100.00%
# Epoch  200/1000 Cost: 0.080574 Accuracy 100.00%
# Epoch  210/1000 Cost: 0.077507 Accuracy 100.00%
# Epoch  220/1000 Cost: 0.074670 Accuracy 100.00%
# Epoch  230/1000 Cost: 0.072039 Accuracy 100.00%
# Epoch  240/1000 Cost: 0.069592 Accuracy 100.00%
# Epoch  250/1000 Cost: 0.067309 Accuracy 100.00%
# Epoch  260/1000 Cost: 0.065175 Accuracy 100.00%
# Epoch  270/1000 Cost: 0.063175 Accuracy 100.00%
# Epoch  280/1000 Cost: 0.061297 Accuracy 100.00%
# Epoch  290/1000 Cost: 0.059530 Accuracy 100.00%
# Epoch  300/1000 Cost: 0.057865 Accuracy 100.00%
# Epoch  310/1000 Cost: 0.056292 Accuracy 100.00%
# Epoch  320/1000 Cost: 0.054804 Accuracy 100.00%
# Epoch  330/1000 Cost: 0.053395 Accuracy 100.00%
# Epoch  340/1000 Cost: 0.052058 Accuracy 100.00%
# Epoch  350/1000 Cost: 0.050787 Accuracy 100.00%
# Epoch  360/1000 Cost: 0.049578 Accuracy 100.00%
# Epoch  370/1000 Cost: 0.048427 Accuracy 100.00%
# Epoch  380/1000 Cost: 0.047329 Accuracy 100.00%
# Epoch  390/1000 Cost: 0.046281 Accuracy 100.00%
# Epoch  400/1000 Cost: 0.045279 Accuracy 100.00%
# Epoch  410/1000 Cost: 0.044320 Accuracy 100.00%
# Epoch  420/1000 Cost: 0.043401 Accuracy 100.00%
# Epoch  430/1000 Cost: 0.042521 Accuracy 100.00%
# Epoch  440/1000 Cost: 0.041676 Accuracy 100.00%
# Epoch  450/1000 Cost: 0.040865 Accuracy 100.00%
# Epoch  460/1000 Cost: 0.040085 Accuracy 100.00%
# Epoch  470/1000 Cost: 0.039335 Accuracy 100.00%
# Epoch  480/1000 Cost: 0.038613 Accuracy 100.00%
# Epoch  490/1000 Cost: 0.037917 Accuracy 100.00%
# Epoch  500/1000 Cost: 0.037247 Accuracy 100.00%
# Epoch  510/1000 Cost: 0.036600 Accuracy 100.00%
# Epoch  520/1000 Cost: 0.035975 Accuracy 100.00%
# Epoch  530/1000 Cost: 0.035372 Accuracy 100.00%
# Epoch  540/1000 Cost: 0.034789 Accuracy 100.00%
# Epoch  550/1000 Cost: 0.034225 Accuracy 100.00%
# Epoch  560/1000 Cost: 0.033679 Accuracy 100.00%
# Epoch  570/1000 Cost: 0.033151 Accuracy 100.00%
# Epoch  580/1000 Cost: 0.032639 Accuracy 100.00%
# Epoch  590/1000 Cost: 0.032143 Accuracy 100.00%
# Epoch  600/1000 Cost: 0.031662 Accuracy 100.00%
# Epoch  610/1000 Cost: 0.031196 Accuracy 100.00%
# Epoch  620/1000 Cost: 0.030743 Accuracy 100.00%
# Epoch  630/1000 Cost: 0.030303 Accuracy 100.00%
# Epoch  640/1000 Cost: 0.029876 Accuracy 100.00%
# Epoch  650/1000 Cost: 0.029461 Accuracy 100.00%
# Epoch  660/1000 Cost: 0.029057 Accuracy 100.00%
# Epoch  670/1000 Cost: 0.028664 Accuracy 100.00%
# Epoch  680/1000 Cost: 0.028282 Accuracy 100.00%
# Epoch  690/1000 Cost: 0.027910 Accuracy 100.00%
# Epoch  700/1000 Cost: 0.027548 Accuracy 100.00%
# Epoch  710/1000 Cost: 0.027195 Accuracy 100.00%
# Epoch  720/1000 Cost: 0.026852 Accuracy 100.00%
# Epoch  730/1000 Cost: 0.026517 Accuracy 100.00%
# Epoch  740/1000 Cost: 0.026190 Accuracy 100.00%
# Epoch  750/1000 Cost: 0.025871 Accuracy 100.00%
# Epoch  760/1000 Cost: 0.025560 Accuracy 100.00%
# Epoch  770/1000 Cost: 0.025257 Accuracy 100.00%
# Epoch  780/1000 Cost: 0.024960 Accuracy 100.00%
# Epoch  790/1000 Cost: 0.024671 Accuracy 100.00%
# Epoch  800/1000 Cost: 0.024388 Accuracy 100.00%
# Epoch  810/1000 Cost: 0.024112 Accuracy 100.00%
# Epoch  820/1000 Cost: 0.023842 Accuracy 100.00%
# Epoch  830/1000 Cost: 0.023578 Accuracy 100.00%
# Epoch  840/1000 Cost: 0.023320 Accuracy 100.00%
# Epoch  850/1000 Cost: 0.023068 Accuracy 100.00%
# Epoch  860/1000 Cost: 0.022820 Accuracy 100.00%
# Epoch  870/1000 Cost: 0.022579 Accuracy 100.00%
# Epoch  880/1000 Cost: 0.022342 Accuracy 100.00%
# Epoch  890/1000 Cost: 0.022110 Accuracy 100.00%
# Epoch  900/1000 Cost: 0.021883 Accuracy 100.00%
# Epoch  910/1000 Cost: 0.021661 Accuracy 100.00%
# Epoch  920/1000 Cost: 0.021443 Accuracy 100.00%
# Epoch  930/1000 Cost: 0.021230 Accuracy 100.00%
# Epoch  940/1000 Cost: 0.021021 Accuracy 100.00%
# Epoch  950/1000 Cost: 0.020816 Accuracy 100.00%
# Epoch  960/1000 Cost: 0.020615 Accuracy 100.00%
# Epoch  970/1000 Cost: 0.020418 Accuracy 100.00%
# Epoch  980/1000 Cost: 0.020224 Accuracy 100.00%
# Epoch  990/1000 Cost: 0.020034 Accuracy 100.00%
# Epoch 1000/1000 Cost: 0.019848 Accuracy 100.00%
