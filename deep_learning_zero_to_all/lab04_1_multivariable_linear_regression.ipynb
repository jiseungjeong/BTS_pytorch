# %% [markdown]
# # 01. 선형회귀

# %% [markdown]
# ## 기본 셋팅

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %% [markdown]
# ## optimizer.zero_grad()가 필요한 이유
# grad가 계속 누적되기 때문

# %%
import torch
w=torch.tensor(2.0,requires_grad=True)

nb_epochs=20
for epoch in range(nb_epochs+1):
    z=2*w
    z.backward()
    print('수식을 w로 미분한 값: {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값: 2.0
# 수식을 w로 미분한 값: 4.0
# 수식을 w로 미분한 값: 6.0
# 수식을 w로 미분한 값: 8.0
# 수식을 w로 미분한 값: 10.0
# 수식을 w로 미분한 값: 12.0
# 수식을 w로 미분한 값: 14.0
# 수식을 w로 미분한 값: 16.0
# 수식을 w로 미분한 값: 18.0
# 수식을 w로 미분한 값: 20.0
# 수식을 w로 미분한 값: 22.0
# 수식을 w로 미분한 값: 24.0
# 수식을 w로 미분한 값: 26.0
# 수식을 w로 미분한 값: 28.0
# 수식을 w로 미분한 값: 30.0
# 수식을 w로 미분한 값: 32.0
# 수식을 w로 미분한 값: 34.0
# 수식을 w로 미분한 값: 36.0
# 수식을 w로 미분한 값: 38.0
# 수식을 w로 미분한 값: 40.0
# 수식을 w로 미분한 값: 42.0

# %% [markdown]
# ## torch.manual_seed()를 하는 이유
# 다른 컴퓨터에서 실행했을 때도 동일한 결과를 얻어내기 위해서

# %%
import torch

# %%
torch.manual_seed(3)
print('랜덤 시드가 3일 때')
for i in range(1,3):
    print(torch.rand(1))
# Out:
# 랜덤 시드가 3일 때
# tensor([0.0043])
# tensor([0.1056])

# %%
torch.manual_seed(5)
print('랜덤 시드가 5일 때')
for i in range(1,3):
    print(torch.rand(1))
# Out:
# 랜덤 시드가 5일 때
# tensor([0.8303])
# tensor([0.1261])

# %%
torch.manual_seed(3)
print('랜덤 시드가 다시 3일 때')
for i in range(1,3):
    print(torch.rand(1))
# Out:
# 랜덤 시드가 다시 3일 때
# tensor([0.0043])
# tensor([0.1056])

# %% [markdown]
# # 02. 자동 미분(Autograd)
# 경사하강법을 직접 코딩하는 것은 까다로움. 파이토치에서 그래서 자동 미분을 지원함. requires_grad=True, backward() 가 자동미분을 수행하는 것임.

# %%
import torch

# %%
w=torch.tensor(2.0, requires_grad=True) # 텐서에 대한 기울기를 저장하겠다는 뜻

y=w**2
z=2*y+5

z.backward() #해당 수식(z)의 w(requires_grad로 지정됨)에 대한 기울기 계산

print('수식을 w로 미분한 값 : {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값 : 8.0

# %% [markdown]
# # 03. 다중 선형 회귀 (Multivariable Linear Regression)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %%
x1_train=torch.FloatTensor([[73],[93],[89],[96],[73]]) # Quiz1
x2_train=torch.FloatTensor([[80],[88],[91],[98],[66]]) # Quiz2
x3_train=torch.FloatTensor([[75],[93],[90],[100],[70]]) # Quiz3
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

# %%
w1=torch.zeros(1,requires_grad=True)
w2=torch.zeros(1, requires_grad=True)
w3=torch.zeros(1, requires_grad=True)
b=torch.zeros(1, requires_grad=True)

# %%
optimizer = optim.SGD([w1,w2,w3,b],lr=1e-5)

nb_epochs=1000
for epoch in range(nb_epochs+1):
    hypothesis=x1_train*w1+x2_train*w2+x3_train*w3+b
    
    cost=torch.mean((hypothesis-y_train)**2)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} w1: {:.3f} w2: {:.3f} w3: {:.3f} b: {:.3f} Cost: {:.6f}'.format(epoch, nb_epochs, w1.item(), w2.item(), w3.item(), b.item(), cost.item()))
# Out:
# Epoch    0/1000 w1: 0.459 w2: 0.458 w3: 0.464 b: 0.005 Cost: 9298.520508
# Epoch  100/1000 w1: 0.674 w2: 0.661 w3: 0.676 b: 0.008 Cost: 1.562946
# Epoch  200/1000 w1: 0.679 w2: 0.655 w3: 0.677 b: 0.008 Cost: 1.496967
# Epoch  300/1000 w1: 0.684 w2: 0.649 w3: 0.677 b: 0.008 Cost: 1.434433
# Epoch  400/1000 w1: 0.689 w2: 0.643 w3: 0.678 b: 0.008 Cost: 1.375144
# Epoch  500/1000 w1: 0.695 w2: 0.638 w3: 0.678 b: 0.009 Cost: 1.318964
# Epoch  600/1000 w1: 0.699 w2: 0.633 w3: 0.679 b: 0.009 Cost: 1.265695
# Epoch  700/1000 w1: 0.704 w2: 0.627 w3: 0.679 b: 0.009 Cost: 1.215217
# Epoch  800/1000 w1: 0.709 w2: 0.622 w3: 0.679 b: 0.009 Cost: 1.167346
# Epoch  900/1000 w1: 0.714 w2: 0.617 w3: 0.680 b: 0.009 Cost: 1.121989
# Epoch 1000/1000 w1: 0.718 w2: 0.612 w3: 0.680 b: 0.009 Cost: 1.078964

# %% [markdown]
# ## 벡터와 행렬 연산으로 바꾸기

# %%
x_train=torch.FloatTensor([[73,80,75],
                          [93,88,93],
                          [89,91,90],
                          [96,98,100],
                          [73,66,70]])
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# torch.Size([5, 3])
# torch.Size([5, 1])

# %%
W=torch.zeros((3,1),requires_grad=True)
b=torch.zeros(1,requires_grad=True)

# %%
optimizer=optim.SGD([W,b],lr=1e-5)
nb_epochs=20
for epoch in range(nb_epochs+1):
    hypothesis=x_train.matmul(W)+b
    
    cost=torch.mean((hypothesis-y_train)**2)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    print('Epoch {:4d}/{} hypothesis: {} Cost: {:.6f}'.format(epoch,nb_epochs,hypothesis.squeeze().detach(),cost.item()))
# Out:
# Epoch    0/20 hypothesis: tensor([0., 0., 0., 0., 0.]) Cost: 29661.800781
# Epoch    1/20 hypothesis: tensor([67.2578, 80.8397, 79.6523, 86.7394, 61.6605]) Cost: 9298.520508
# Epoch    2/20 hypothesis: tensor([104.9128, 126.0990, 124.2466, 135.3015,  96.1821]) Cost: 2915.712402
# Epoch    3/20 hypothesis: tensor([125.9942, 151.4381, 149.2133, 162.4896, 115.5097]) Cost: 915.040527
# Epoch    4/20 hypothesis: tensor([137.7967, 165.6247, 163.1911, 177.7112, 126.3307]) Cost: 287.936096
# Epoch    5/20 hypothesis: tensor([144.4044, 173.5674, 171.0168, 186.2332, 132.3891]) Cost: 91.371063
# Epoch    6/20 hypothesis: tensor([148.1035, 178.0143, 175.3980, 191.0042, 135.7812]) Cost: 29.758249
# Epoch    7/20 hypothesis: tensor([150.1744, 180.5042, 177.8509, 193.6753, 137.6805]) Cost: 10.445267
# Epoch    8/20 hypothesis: tensor([151.3336, 181.8983, 179.2240, 195.1707, 138.7440]) Cost: 4.391237
# ...

# %% [markdown]
# # 04. nn.Module로 구현하는 선형 회귀

# %%
# import torch.nn as nn
# model=nn.Linear(input_dim, output_dim)

# import torch.nn.functional as F
# cost=F.mse_loss(prediction, y_train)

# %% [markdown]
# ## 04-1 단순 선형회귀

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
torch.manual_seed(1)

# %%
model=nn.Linear(1,1)
print(list(model.parameters()))
x_train=torch.FloatTensor([[1],[2],[3]])
y_train=torch.FloatTensor([[2],[4],[6]])
# Out:
# [Parameter containing:
# tensor([[-0.1939]], requires_grad=True), Parameter containing:
# tensor([0.4694], requires_grad=True)]

# %%
optimizer=torch.optim.SGD(model.parameters(), lr=0.01)

# %%
nb_epochs=2000
for epoch in range(nb_epochs + 1):
        
    prediction=model(x_train)
    
    cost=F.mse_loss(prediction, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} Cost {:6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch    0/2000 Cost 14.714844
# Epoch  100/2000 Cost 0.127436
# Epoch  200/2000 Cost 0.078748
# Epoch  300/2000 Cost 0.048661
# Epoch  400/2000 Cost 0.030070
# Epoch  500/2000 Cost 0.018581
# Epoch  600/2000 Cost 0.011482
# Epoch  700/2000 Cost 0.007095
# Epoch  800/2000 Cost 0.004384
# Epoch  900/2000 Cost 0.002709
# Epoch 1000/2000 Cost 0.001674
# Epoch 1100/2000 Cost 0.001035
# Epoch 1200/2000 Cost 0.000639
# Epoch 1300/2000 Cost 0.000395
# Epoch 1400/2000 Cost 0.000244
# Epoch 1500/2000 Cost 0.000151
# Epoch 1600/2000 Cost 0.000093
# Epoch 1700/2000 Cost 0.000058
# Epoch 1800/2000 Cost 0.000036
# Epoch 1900/2000 Cost 0.000022
# Epoch 2000/2000 Cost 0.000014

# %% [markdown]
# ## 04-2 다중 선형 회귀 구현하기

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
torch.manual_seed(1)

# %%
# x_train=torch.FloatTensor([[73,80,75],
#                           [93,88,93],
#                           [89,91,90],
#                           [96,98,100],
#                           [73,66,70]])
x_train=torch.FloatTensor([[3,6],
                          [2,5],
                          [4,3]])
# y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])
y_train=torch.FloatTensor([[18],[12],[14]])

# %%
model=nn.Linear(2,1)
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[ 0.3643, -0.3121]], requires_grad=True), Parameter containing:
# tensor([-0.1371], requires_grad=True)]

# %%
optimizer=torch.optim.SGD(model.parameters(), lr=1e-5)

nb_epochs=100000
for epoch in range(nb_epochs+1):
    
    prediction=model(x_train)
    
    cost=F.mse_loss(prediction, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs,cost.item()))
# Out:
# Epoch    0/100000 Cost: 0.800683
# Epoch  100/100000 Cost: 0.800369
# Epoch  200/100000 Cost: 0.800056
# Epoch  300/100000 Cost: 0.799744
# Epoch  400/100000 Cost: 0.799432
# Epoch  500/100000 Cost: 0.799123
# Epoch  600/100000 Cost: 0.798817
# Epoch  700/100000 Cost: 0.798523
# Epoch  800/100000 Cost: 0.798227
# Epoch  900/100000 Cost: 0.797934
# Epoch 1000/100000 Cost: 0.797640
# Epoch 1100/100000 Cost: 0.797349
# Epoch 1200/100000 Cost: 0.797057
# Epoch 1300/100000 Cost: 0.796766
# Epoch 1400/100000 Cost: 0.796477
# Epoch 1500/100000 Cost: 0.796188
# Epoch 1600/100000 Cost: 0.795899
# Epoch 1700/100000 Cost: 0.795611
# Epoch 1800/100000 Cost: 0.795325
# Epoch 1900/100000 Cost: 0.795041
# Epoch 2000/100000 Cost: 0.794759
# Epoch 2100/100000 Cost: 0.794479
# Epoch 2200/100000 Cost: 0.794197
# Epoch 2300/100000 Cost: 0.793918
# Epoch 2400/100000 Cost: 0.793637
# Epoch 2500/100000 Cost: 0.793369
# Epoch 2600/100000 Cost: 0.793101
# Epoch 2700/100000 Cost: 0.792835
# ...

# %%
# new_var=torch.FloatTensor([[73,80,75]])
new_var=torch.FloatTensor([[6,2]])
pred_y=model(new_var)
print(pred_y)
# print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# tensor([[16.9867]], grad_fn=<AddmmBackward0>)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[0.9778, 0.4539, 0.5768]], requires_grad=True), Parameter containing:
# tensor([0.2802], requires_grad=True)]

# %% [markdown]
# # 05. 클래스로 파이토치 모델 구현하기
# ## 단순 선형 회귀 모델

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
torch.manual_seed(1)

# %%
x_train=torch.FloatTensor([[1],[2],[3]])
y_train=torch.FloatTensor([[2],[4],[6]])

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(1,1)
        
    def forward(self, x):
        return self.linear(x)
    
model=LinearRegressionModel()
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
nb_epochs=2000
for epoch in range(nb_epochs+1):
    prediction=model(x_train)
    cost=F.mse_loss(prediction, y_train)
    
    optimizer.zero_grad()
    
    cost.backward()
    
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch    0/2000 Cost: 18.562185
# Epoch  100/2000 Cost: 0.128051
# Epoch  200/2000 Cost: 0.079128
# Epoch  300/2000 Cost: 0.048896
# Epoch  400/2000 Cost: 0.030215
# Epoch  500/2000 Cost: 0.018671
# Epoch  600/2000 Cost: 0.011538
# Epoch  700/2000 Cost: 0.007129
# Epoch  800/2000 Cost: 0.004406
# Epoch  900/2000 Cost: 0.002722
# Epoch 1000/2000 Cost: 0.001682
# Epoch 1100/2000 Cost: 0.001040
# Epoch 1200/2000 Cost: 0.000642
# Epoch 1300/2000 Cost: 0.000397
# Epoch 1400/2000 Cost: 0.000245
# Epoch 1500/2000 Cost: 0.000152
# Epoch 1600/2000 Cost: 0.000094
# Epoch 1700/2000 Cost: 0.000058
# Epoch 1800/2000 Cost: 0.000036
# Epoch 1900/2000 Cost: 0.000022
# Epoch 2000/2000 Cost: 0.000014

# %% [markdown]
# ## 다중 선형 회귀 모델

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
torch.manual_seed(1)

# %%
x_train=torch.FloatTensor([[73,80,75],
                           [93,88,93],
                           [89,91,90],
                           [96,98,100],
                           [73,66,70]])
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

# %%
class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(3,1)
        
    def forward(self, x):
        return self.linear(x)

model=MultivariateLinearRegressionModel()
optimizer=torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs=2000
for epoch in range(nb_epochs+1):
    prediction=model(x_train)
    cost=F.mse_loss(prediction, y_train)
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch    0/2000 Cost: 39633.414062
# Epoch  100/2000 Cost: 11.480746
# Epoch  200/2000 Cost: 10.894592
# Epoch  300/2000 Cost: 10.339335
# Epoch  400/2000 Cost: 9.813351
# Epoch  500/2000 Cost: 9.315010
# Epoch  600/2000 Cost: 8.842962
# Epoch  700/2000 Cost: 8.395753
# Epoch  800/2000 Cost: 7.972028
# Epoch  900/2000 Cost: 7.570637
# Epoch 1000/2000 Cost: 7.190376
# Epoch 1100/2000 Cost: 6.830142
# Epoch 1200/2000 Cost: 6.488811
# Epoch 1300/2000 Cost: 6.165472
# Epoch 1400/2000 Cost: 5.859105
# Epoch 1500/2000 Cost: 5.568909
# Epoch 1600/2000 Cost: 5.293931
# Epoch 1700/2000 Cost: 5.033408
# Epoch 1800/2000 Cost: 4.786575
# Epoch 1900/2000 Cost: 4.552718
# Epoch 2000/2000 Cost: 4.331151
